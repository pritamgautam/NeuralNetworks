# %% [markdown]
# # Load the PIMA diabetes data
# # some pandas math stuff
# # correlation and plotting correlation (matplotlib)
# # check null values, print how many null values for each of them, impute null values with mean and show the new data
# # split data into test and train
# # check ratio of train to test
# # use different model, print confusion matrix, percent and scores??
# # use cross validation

# %%
import pandas as pd
dataframe = pd.read_csv("../PythonNotebooksIL/pima-data.csv")

# %%
print(dataframe)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# 5           5           116            74          0        0  25.6
# 6           3            78            50         32       88  31.0
# 7          10           115             0          0        0  35.3
# 8           2           197            70         45      543  30.5
# 9           8           125            96          0        0   0.0
# 10          4           110            92          0        0  37.6
# 11         10           168            74          0        0  38.0
# 12         10           139            80          0        0  27.1
# ...

# %%
dataframe.mean()
# Out:
# num_preg          3.845052
# glucose_conc    120.894531
# diastolic_bp     69.105469
# thickness        20.536458
# insulin          79.799479
# bmi              31.992578
# diab_pred         0.471876
# age              33.240885
# skin              0.809136
# diabetes          0.348958
# dtype: float64

# %%
dataframe.corr()
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
dataframe.isnull().values.any()
# Out:
# False

# %%
mapping_dictionary = {True : 1, False : 0}
dataframe['diabetes'] = dataframe['diabetes'].map(mapping_dictionary)

# %%
print(dataframe)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# 5           5           116            74          0        0  25.6
# 6           3            78            50         32       88  31.0
# 7          10           115             0          0        0  35.3
# 8           2           197            70         45      543  30.5
# 9           8           125            96          0        0   0.0
# 10          4           110            92          0        0  37.6
# 11         10           168            74          0        0  38.0
# 12         10           139            80          0        0  27.1
# ...

# %%
print("count of true is {0}".format(len(dataframe.loc[dataframe['diabetes']]==1)))
# Out:
# count of true is 768

# %%
len(dataframe.loc[dataframe['diabetes']==1])
# Out:
# 268

# %%
feature_names = ['num_preg','glucose_conc','diastolic_bp','thickness','insulin','bmi','diab_pred','age','skin']
classification = ['diabetes']

# %%
#x = dataframe[feature_names]
#y = dataframe[classification]
z = dataframe['diastolic_bp']
print(z)
x = dataframe.iloc[:,0:9]
print(x)
y = dataframe.iloc[:,9]
print(y)
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
# 5      74
# 6      50
# 7       0
# 8      70
# 9      96
# 10     92
# 11     74
# 12     80
# 13     60
# 14     72
# 15      0
# 16     84
# 17     74
# 18     30
# 19     70
# 20     88
# 21     84
# 22     90
# 23     80
# 24     94
# 25     70
# 26     76
# 27     66
# 28     82
# 29     92
#        ..
# 738    60
# 739    74
# 740    80
# 741    44
# 742    58
# 743    94
# 744    88
# 745    84
# 746    94
# 747    74
# 748    70
# 749    62
# 750    70
# 751    78
# 752    62
# 753    88
# 754    78
# 755    88
# 756    90
# 757    72
# 758    76
# 759    92
# 760    58
# 761    74
# 762    62
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: diastolic_bp, dtype: int64
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# ...

# %%
import numpy as np
from sklearn.cross_validation import train_test_split
train, test = train_test_split(dataframe, test_size=0.2)
x_train = train[feature_names]
x_test = train[classification]
y_train = test[feature_names]
y_test = test[classification]

print(x_train)
#train, test = train_test_split(df, test_size=0.2)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 464        10           115            98          0        0  24.0
# 638         7            97            76         32       91  40.9
# 221         2           158            90          0        0  31.6
# 10          4           110            92          0        0  37.6
# 160         4           151            90         38        0  29.7
# 582        12           121            78         17        0  26.5
# 129         0           105            84          0        0  27.9
# 168         4           110            66          0        0  31.9
# 423         2           115            64         22        0  30.8
# 518        13            76            60          0        0  32.8
# 486         1           139            62         41      480  40.7
# 222         7           119             0          0        0  25.2
# 95          6           144            72         27      228  33.9
# ...

# %%
print(x_train)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 503         7            94            64         25       79  33.3
# 616         6           117            96          0        0  28.7
# 270        10           101            86         37        0  45.6
# 257         2           114            68         22        0  28.7
# 428         0           135            94         46      145  40.6
# 484         0           145             0          0        0  44.2
# 37          9           102            76         37        0  32.9
# 461         1            71            62          0        0  21.8
# 679         2           101            58         17      265  24.2
# 230         4           142            86          0        0  44.0
# 30          5           109            75         26        0  36.0
# 113         4            76            62          0        0  34.0
# 298        14           100            78         25      184  36.6
# ...

# %%
from sklearn.cross_validation import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
print (xtrain)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 684         5           136            82          0        0   0.0
# 636         5           104            74          0        0  28.8
# 231         6           134            80         37      370  46.2
# 537         0            57            60          0        0  21.7
# 381         0           105            68         22        0  20.0
# 610         3           106            54         21      158  30.9
# 28         13           145            82         19      110  22.2
# 458        10           148            84         48      237  37.6
# 718         1           108            60         46      178  35.5
# 226         0           101            76          0        0  35.7
# 410         6           102            90         39        0  35.7
# 205         5           111            72         28        0  23.9
# 670         6           165            68         26      168  33.6
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(xtrain, ytrain)
predicted_rfc = rfc.predict(xtest)

from sklearn.metrics import accuracy_score

print(accuracy_score(ytest, predicted_rfc))
# Out:
# 0.733766233766

# %%
from sklearn import metrics
metrics.accuracy_score(ytest,predicted_rfc)
# Out:
# 0.73376623376623373

# %%
from sklearn.metrics import confusion_matrix
print (confusion_matrix(ytest, predicted_rfc))
# Out:
# [[90 11]
#  [30 23]]

# %%
print(metrics.classification_report(ytest, predicted_rfc))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.89      0.81       101
#           1       0.68      0.43      0.53        53
#
# avg / total       0.72      0.73      0.72       154
